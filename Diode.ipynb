# %% [markdown]
# <a href="https://colab.research.google.com/github/VinayakG2002/README.md/blob/main/Diode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
  
# line 1 points
x1 = [2.86,2.54,2.49,2.39,2.35,2.31,2.29,2.23,1.75,1.29,0.87]
y1 = [24.90,7.82,5.14,2.54,1.98,1.49,1.28,0.97,0.75,0.66,0.57]
# plotting the line 1 points 
plt.plot(x1, y1,color='green',marker='x',markersize=6,label = "GREEN")
  
# line 2 points
x2 = [2.14,1.99,1.88,1.84,1.82,1.78,1.76,1.73,1.62,1.28,0.73]
y2 = [24.2,10.04,3.84,2.44,1.85,1.26,1.042,0.89,0.74,0.66,0.48]
# plotting the line 2 points 
plt.plot(x2, y2,color='red',marker='x',markersize=6,label = "RED")
x3 = [0.787,0.73,0.70,0.68,0.64,0.62,0.6,0.58,0.57,0.56,0.53]
y3 = [24.9,10.3,6.6,5.00,2.56,1.72,1.25,0.96,0.78,0.70,0.58]
plt.plot(x3, y3,color='black',marker='x',markersize=6,label = "Diode")
# naming the x axis
plt.xlabel('Vd')
# naming the y axis
plt.ylabel('Id')
# giving a title to my graph
plt.title('IV Plots- 3 Diodes')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()
